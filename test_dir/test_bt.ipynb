# %%
import pandas as pd
import numpy as np
import vectorbt as vbt

# 读取本地 data 文件夹的 BTC/USDT 1d 数据
df = pd.read_csv('data/spot/binance/1d/BTC_USDT.csv')
df['date'] = pd.to_datetime(df['datetime'])
df.set_index('date', inplace=True)

# 计算连续涨跌天数
close = df['close']
ret = close.pct_change()
up = ret > 0
down = ret < 0

up_streak = up.rolling(3).sum() == 3
down_streak = down.rolling(3).sum() == 3

# 计算3天涨跌幅
change_3d = close.pct_change(3).abs()

# 生成信号
entries = up_streak.shift(1).fillna(False)  # 连涨3天后第4天开多
exits = down_streak.shift(1).fillna(False)  # 连跌3天后第4天开空

# 止盈止损幅度
take_profit = change_3d.shift(1).fillna(0)
stop_loss = change_3d.shift(1).fillna(0)

# 用vectorbt回测
pf = vbt.Portfolio.from_signals(
    close,
    entries,
    exits,
    sl_stop=stop_loss,      # 止损百分比
    tp_stop=take_profit,    # 止盈百分比
    direction='both',       # 多空都做
    freq='1D'
)

print(pf.stats())
# 将回测结果的交互式图表保存为HTML文件，便于浏览器打开
fig = pf.plot()
fig.write_html("portfolio_result.html")
print("已保存为 portfolio_result.html，可用浏览器打开查看。")
# Out:
# Start                               2017-08-17 00:00:00
# End                                 2025-09-07 00:00:00
# Period                               2944 days 00:00:00
# Start Value                                       100.0
# End Value                                    178.222659
# Total Return [%]                              78.222659
# Benchmark Return [%]                        2493.588451
# Max Gross Exposure [%]                            100.0
# Total Fees Paid                                     0.0
# Max Drawdown [%]                              66.138006
# Max Drawdown Duration                1500 days 00:00:00
# Total Trades                                        284
# Total Closed Trades                                 283
# Total Open Trades                                     1
# Open Trade PnL                                      0.0
# Win Rate [%]                                   47.70318
# Best Trade [%]                                45.598031
# Worst Trade [%]                              -25.405405
# Avg Winning Trade [%]                           9.04312
# Avg Losing Trade [%]                          -6.908543
# Avg Winning Trade Duration              7 days 15:17:20
# Avg Losing Trade Duration     6 days 23:11:21.081081081
# Profit Factor                                  1.042222
# Expectancy                                     0.276405
# Sharpe Ratio                                   0.405514
# Calmar Ratio                                     0.1123
# Omega Ratio                                    1.078634
# Sortino Ratio                                   0.60557
# Name: close, dtype: object
# 已保存为 portfolio_result.html，可用浏览器打开查看。

# %%
import ccxt
import pandas as pd
import datetime

# 步骤1：用ccxt获取Binance BTC/USDT 1d数据

exchange = ccxt.binance()
since = exchange.parse8601('2020-01-01T00:00:00Z')
bars = []
limit = 1000
symbol = 'BTC/USDT'
timeframe = '1d'
while True:
    ohlcv = exchange.fetch_ohlcv(symbol, timeframe, since=since, limit=limit)
    if not ohlcv:
        break
    bars += ohlcv
    since = ohlcv[-1][0] + 24*60*60*1000  # 下一天
    if len(ohlcv) < limit:
        break

df = pd.DataFrame(bars, columns=['timestamp', 'open', 'high', 'low', 'close', 'volume'])
df['date'] = pd.to_datetime(df['timestamp'], unit='ms')
df.set_index('date', inplace=True)

# %%
import ccxt
from config import proxies

# 用你的OKX API信息替换下面内容
api_key = '4c7e2162-3f63-4293-8451-dcea44fb98cd'
api_secret = '9C2570C37CA9B66F0E0515D5894D493F'
api_passphrase = 'Buyao034971!'

okx = ccxt.okx({
    'apiKey': api_key,
    'secret': api_secret,
    'password': api_passphrase,
    'enableRateLimit': True,
    'proxies': proxies
})

# 切换到实盘（默认是实盘，若要测试网需加test参数）
# okx.set_sandbox_mode(True)  # 测试网用，实盘不要加

# %%
# check account balance
balance = okx.fetch_balance()

# %%
balance
# Out:
# {'info': {'code': '0',
#   'data': [{'adjEq': '',
#     'availEq': '',
#     'borrowFroz': '',
#     'details': [{'accAvgPx': '',
#       'autoLendAmt': '0',
#       'autoLendMtAmt': '0',
#       'autoLendStatus': 'unsupported',
#       'availBal': '162.85103910589436',
#       'availEq': '162.85103910589436',
#       'borrowFroz': '',
#       'cashBal': '162.85103910589436',
#       'ccy': 'USDT',
#       'clSpotInUseAmt': '',
#       'colBorrAutoConversion': '0',
#       'colRes': '0',
#       'collateralEnabled': False,
#       'collateralRestrict': False,
#       'crossLiab': '',
#       'disEq': '0',
#       'eq': '162.85103910589436',
#       'eqUsd': '162.85429612667647',
#       'fixedBal': '0',
#       'frozenBal': '0',
#       'imr': '0',
#       'interest': '',
#       'isoEq': '0',
#       'isoLiab': '',
#       'isoUpl': '0',
#       'liab': '',
#       'maxLoan': '',
#       'maxSpotInUse': '',
#       'mgnRatio': '',
#       'mmr': '0',
#       'notionalLever': '0',
#       'openAvgPx': '',
#       'ordFrozen': '0',
#       'rewardBal': '0',
#       'smtSyncEq': '0',
#       'spotBal': '',
#       'spotCopyTradingEq': '0',
#       'spotInUseAmt': '',
#       'spotIsoBal': '0',
#       'spotUpl': '',
#       'spotUplRatio': '',
#       'stgyEq': '0',
#       'totalPnl': '',
#       'totalPnlRatio': '',
#       'twap': '0',
#       'uTime': '1757347721095',
#       'upl': '0',
#       'uplLiab': ''},
#      {'accAvgPx': '0.0000265823302672',
#       'autoLendAmt': '0',
#       'autoLendMtAmt': '0',
#       'autoLendStatus': 'unsupported',
#       'availBal': '4704853.437',
#       'availEq': '4704853.437',
#       'borrowFroz': '',
#       'cashBal': '4704853.437',
#       'ccy': 'PEPE',
#       'clSpotInUseAmt': '',
#       'colBorrAutoConversion': '0',
#       'colRes': '0',
#       'collateralEnabled': False,
#       'collateralRestrict': False,
#       'crossLiab': '',
#       'disEq': '0',
#       'eq': '4704853.437',
#       'eqUsd': '48.375303039234005',
#       'fixedBal': '0',
#       'frozenBal': '0',
#       'imr': '0',
#       'interest': '',
#       'isoEq': '0',
#       'isoLiab': '',
#       'isoUpl': '0',
#       'liab': '',
#       'maxLoan': '',
#       'maxSpotInUse': '',
#       'mgnRatio': '',
#       'mmr': '0',
#       'notionalLever': '0',
#       'openAvgPx': '0.000026555747937',
#       'ordFrozen': '0',
#       'rewardBal': '0',
#       'smtSyncEq': '0',
#       'spotBal': '4704853.437',
#       'spotCopyTradingEq': '0',
#       'spotInUseAmt': '',
#       'spotIsoBal': '0',
#       'spotUpl': '-76.5655989142661',
#       'spotUplRatio': '-0.6128145204423281',
#       'stgyEq': '0',
#       'totalPnl': '-76.6906648819888',
#       'totalPnlRatio': '-0.6132017059212712',
#       'twap': '0',
#       'uTime': '1733706313584',
#       'upl': '0',
#       'uplLiab': ''},
#      {'accAvgPx': '0.0000000049874901',
#       'autoLendAmt': '0',
#       'autoLendMtAmt': '0',
#       'autoLendStatus': 'unsupported',
#       'availBal': '30092590788.498',
#       'availEq': '30092590788.498',
#       'borrowFroz': '',
#       'cashBal': '30092590788.498',
#       'ccy': 'BABYDOGE',
#       'clSpotInUseAmt': '',
#       'colBorrAutoConversion': '0',
#       'colRes': '0',
#       'collateralEnabled': False,
#       'collateralRestrict': False,
#       'crossLiab': '',
#       'disEq': '0',
#       'eq': '30092590788.498',
#       'eqUsd': '38.75925693558543',
#       'fixedBal': '0',
#       'frozenBal': '0',
#       'imr': '0',
#       'interest': '',
#       'isoEq': '0',
#       'isoLiab': '',
#       'isoUpl': '0',
#       'liab': '',
#       'maxLoan': '',
#       'maxSpotInUse': '',
#       'mgnRatio': '',
#       'mmr': '0',
#       'notionalLever': '0',
#       'openAvgPx': '0.0000000049825027',
#       'ordFrozen': '0',
#       'rewardBal': '0',
#       'smtSyncEq': '0',
#       'spotBal': '30092590788.498',
#       'spotCopyTradingEq': '0',
#       'spotInUseAmt': '',
#       'spotIsoBal': '0',
#       'spotUpl': '-111.17715791810099',
#       'spotUplRatio': '-0.7414953733993962',
#       'stgyEq': '0',
#       'totalPnl': '-111.32724306374217',
#       'totalPnlRatio': '-0.7417538756932898',
#       'twap': '0',
#       'uTime': '1733723570310',
#       'upl': '0',
#       'uplLiab': ''},
#      {'accAvgPx': '0.0000000176952934',
#       'autoLendAmt': '0',
#       'autoLendMtAmt': '0',
#       'autoLendStatus': 'unsupported',
#       'availBal': '848047537.566',
#       'availEq': '848047537.566',
#       'borrowFroz': '',
#       'cashBal': '848047537.566',
#       'ccy': 'POLYDOGE',
#       'clSpotInUseAmt': '',
#       'colBorrAutoConversion': '0',
#       'colRes': '0',
#       'collateralEnabled': False,
#       'collateralRestrict': False,
#       'crossLiab': '',
#       'disEq': '0',
#       'eq': '848047537.566',
#       'eqUsd': '3.908651100641694',
#       'fixedBal': '0',
#       'frozenBal': '0',
#       'imr': '0',
#       'interest': '',
#       'isoEq': '0',
#       'isoLiab': '',
#       'isoUpl': '0',
#       'liab': '',
#       'maxLoan': '',
#       'maxSpotInUse': '',
#       'mgnRatio': '',
#       'mmr': '0',
#       'notionalLever': '0',
#       'openAvgPx': '0.0000000176775981',
#       'ordFrozen': '0',
#       'rewardBal': '0',
#       'smtSyncEq': '0',
#       'spotBal': '848047537.566',
#       'spotCopyTradingEq': '0',
#       'spotInUseAmt': '',
#       'spotIsoBal': '0',
#       'spotUpl': '-11.082792438144706',
#       'spotUplRatio': '-0.7392745341348155',
#       'stgyEq': '0',
#       'totalPnl': '-11.097798888133479',
#       'totalPnlRatio': '-0.7395352596006807',
#       'twap': '0',
#       'uTime': '1733729418299',
#       'upl': '0',
#       'uplLiab': ''},
#      {'accAvgPx': '',
#       'autoLendAmt': '0',
#       'autoLendMtAmt': '0',
#       'autoLendStatus': 'unsupported',
#       'availBal': '0.000000945',
#       'availEq': '0.000000945',
#       'borrowFroz': '',
#       'cashBal': '0.000000945',
#       'ccy': 'ETH',
#       'clSpotInUseAmt': '',
#       'colBorrAutoConversion': '0',
#       'colRes': '0',
#       'collateralEnabled': False,
#       'collateralRestrict': False,
#       'crossLiab': '',
#       'disEq': '0',
#       'eq': '0.000000945',
#       'eqUsd': '0.00411402915',
#       'fixedBal': '0',
#       'frozenBal': '0',
#       'imr': '0',
#       'interest': '',
#       'isoEq': '0',
#       'isoLiab': '',
#       'isoUpl': '0',
#       'liab': '',
#       'maxLoan': '',
#       'maxSpotInUse': '',
#       'mgnRatio': '',
#       'mmr': '0',
#       'notionalLever': '0',
#       'openAvgPx': '',
#       'ordFrozen': '0',
#       'rewardBal': '0',
#       'smtSyncEq': '0',
#       'spotBal': '',
#       'spotCopyTradingEq': '0',
#       'spotInUseAmt': '',
#       'spotIsoBal': '0',
#       'spotUpl': '',
#       'spotUplRatio': '',
#       'stgyEq': '0',
#       'totalPnl': '',
#       'totalPnlRatio': '',
#       'twap': '0',
#       'uTime': '1757347721095',
#       'upl': '0',
#       'uplLiab': ''},
#      {'accAvgPx': '',
#       'autoLendAmt': '0',
#       'autoLendMtAmt': '0',
#       'autoLendStatus': 'unsupported',
#       'availBal': '0.00000000771',
#       'availEq': '0.00000000771',
#       'borrowFroz': '',
#       'cashBal': '0.00000000771',
#       'ccy': 'BTC',
#       'clSpotInUseAmt': '',
#       'colBorrAutoConversion': '0',
#       'colRes': '0',
#       'collateralEnabled': False,
#       'collateralRestrict': False,
#       'crossLiab': '',
#       'disEq': '0',
#       'eq': '0.00000000771',
#       'eqUsd': '0.000866526129',
#       'fixedBal': '0',
#       'frozenBal': '0',
#       'imr': '0',
#       'interest': '',
#       'isoEq': '0',
#       'isoLiab': '',
#       'isoUpl': '0',
#       'liab': '',
#       'maxLoan': '',
#       'maxSpotInUse': '',
#       'mgnRatio': '',
#       'mmr': '0',
#       'notionalLever': '0',
#       'openAvgPx': '',
#       'ordFrozen': '0',
#       'rewardBal': '0',
#       'smtSyncEq': '0',
#       'spotBal': '',
#       'spotCopyTradingEq': '0',
#       'spotInUseAmt': '',
#       'spotIsoBal': '0',
#       'spotUpl': '',
#       'spotUplRatio': '',
#       'stgyEq': '0',
#       'totalPnl': '',
#       'totalPnlRatio': '',
#       'twap': '0',
#       'uTime': '1731512563026',
#       'upl': '0',
#       'uplLiab': ''},
#      {'accAvgPx': '',
#       'autoLendAmt': '0',
#       'autoLendMtAmt': '0',
#       'autoLendStatus': 'unsupported',
#       'availBal': '0.0000009808',
#       'availEq': '0.0000009808',
#       'borrowFroz': '',
#       'cashBal': '0.0000009808',
#       'ccy': 'OKB',
#       'clSpotInUseAmt': '',
#       'colBorrAutoConversion': '0',
#       'colRes': '2',
#       'collateralEnabled': False,
#       'collateralRestrict': True,
#       'crossLiab': '',
#       'disEq': '0',
#       'eq': '0.0000009808',
#       'eqUsd': '0.00018654816',
#       'fixedBal': '0',
#       'frozenBal': '0',
#       'imr': '0',
#       'interest': '',
#       'isoEq': '0',
#       'isoLiab': '',
#       'isoUpl': '0',
#       'liab': '',
#       'maxLoan': '',
#       'maxSpotInUse': '',
#       'mgnRatio': '',
#       'mmr': '0',
#       'notionalLever': '0',
#       'openAvgPx': '',
#       'ordFrozen': '0',
#       'rewardBal': '0',
#       'smtSyncEq': '0',
#       'spotBal': '',
#       'spotCopyTradingEq': '0',
#       'spotInUseAmt': '',
#       'spotIsoBal': '0',
#       'spotUpl': '',
#       'spotUplRatio': '',
#       'stgyEq': '0',
#       'totalPnl': '',
#       'totalPnlRatio': '',
#       'twap': '0',
#       'uTime': '1731512556054',
#       'upl': '0',
#       'uplLiab': ''},
#      {'accAvgPx': '',
#       'autoLendAmt': '0',
#       'autoLendMtAmt': '0',
#       'autoLendStatus': 'unsupported',
#       'availBal': '0.000000602',
#       'availEq': '0.000000602',
#       'borrowFroz': '',
#       'cashBal': '0.000000602',
#       'ccy': 'SOL',
#       'clSpotInUseAmt': '',
#       'colBorrAutoConversion': '0',
#       'colRes': '0',
#       'collateralEnabled': False,
#       'collateralRestrict': False,
#       'crossLiab': '',
#       'disEq': '0',
#       'eq': '0.000000602',
#       'eqUsd': '0.00012893636',
#       'fixedBal': '0',
#       'frozenBal': '0',
#       'imr': '0',
#       'interest': '',
#       'isoEq': '0',
#       'isoLiab': '',
#       'isoUpl': '0',
#       'liab': '',
#       'maxLoan': '',
#       'maxSpotInUse': '',
#       'mgnRatio': '',
#       'mmr': '0',
#       'notionalLever': '0',
#       'openAvgPx': '',
#       'ordFrozen': '0',
#       'rewardBal': '0',
#       'smtSyncEq': '0',
#       'spotBal': '',
#       'spotCopyTradingEq': '0',
#       'spotInUseAmt': '',
#       'spotIsoBal': '0',
#       'spotUpl': '',
#       'spotUplRatio': '',
#       'stgyEq': '0',
#       'totalPnl': '',
#       'totalPnlRatio': '',
#       'twap': '0',
#       'uTime': '1725729521316',
#       'upl': '0',
#       'uplLiab': ''}],
#     'imr': '',
#     'isoEq': '0',
#     'mgnRatio': '',
#     'mmr': '',
#     'notionalUsd': '',
#     'notionalUsdForBorrow': '',
#     'notionalUsdForFutures': '',
#     'notionalUsdForOption': '',
#     'notionalUsdForSwap': '',
#     'ordFroz': '',
#     'totalEq': '253.9028032419366',
#     'uTime': '1757348181264',
#     'upl': ''}],
#   'msg': ''},
#  'USDT': {'free': 162.85103910589436,
#   'used': 0.0,
#   'total': 162.85103910589436},
#  'PEPE': {'free': 4704853.437, 'used': 0.0, 'total': 4704853.437},
#  'BABYDOGE': {'free': 30092590788.498, 'used': 0.0, 'total': 30092590788.498},
#  'POLYDOGE': {'free': 848047537.566, 'used': 0.0, 'total': 848047537.566},
#  'ETH': {'free': 9.45e-07, 'used': 0.0, 'total': 9.45e-07},
#  'BTC': {'free': 7.71e-09, 'used': 0.0, 'total': 7.71e-09},
#  'OKB': {'free': 9.808e-07, 'used': 0.0, 'total': 9.808e-07},
#  'SOL': {'free': 6.02e-07, 'used': 0.0, 'total': 6.02e-07},
#  'timestamp': 1757348181264,
#  'datetime': '2025-09-08T16:16:21.264Z',
#  'free': {'USDT': 162.85103910589436,
#   'PEPE': 4704853.437,
#   'BABYDOGE': 30092590788.498,
#   'POLYDOGE': 848047537.566,
#   'ETH': 9.45e-07,
#   'BTC': 7.71e-09,
#   'OKB': 9.808e-07,
#   'SOL': 6.02e-07},
#  'used': {'USDT': 0.0,
#   'PEPE': 0.0,
#   'BABYDOGE': 0.0,
#   'POLYDOGE': 0.0,
#   'ETH': 0.0,
#   'BTC': 0.0,
#   'OKB': 0.0,
#   'SOL': 0.0},
#  'total': {'USDT': 162.85103910589436,
#   'PEPE': 4704853.437,
#   'BABYDOGE': 30092590788.498,
#   'POLYDOGE': 848047537.566,
#   'ETH': 9.45e-07,
#   'BTC': 7.71e-09,
#   'OKB': 9.808e-07,
#   'SOL': 6.02e-07}}

# %%
print(okx.markets['PEPE/USDT']['limits'])
# Out:
# {'leverage': {'min': 1.0, 'max': 10.0}, 'amount': {'min': 100000.0, 'max': None}, 'price': {'min': None, 'max': None}, 'cost': {'min': None, 'max': 1000000.0}}

# %%
# 下单示例：买入现货POLYDOGE/USDT，市价买入0.001 POLYDOGE
symbol = 'PEPE/USDT'
order = okx.create_market_buy_order(symbol, 100000.0)
print(order)
# Out:
# {'info': {'clOrdId': '6b9ad766b55dBCDEeea379f064c39c86', 'ordId': '2846954839696973824', 'sCode': '0', 'sMsg': 'Order placed', 'tag': '6b9ad766b55dBCDE', 'ts': '1757348265955'}, 'id': '2846954839696973824', 'clientOrderId': '6b9ad766b55dBCDEeea379f064c39c86', 'timestamp': None, 'datetime': None, 'lastTradeTimestamp': None, 'lastUpdateTimestamp': None, 'symbol': 'PEPE/USDT', 'type': 'market', 'timeInForce': None, 'postOnly': None, 'side': 'buy', 'price': None, 'stopLossPrice': None, 'takeProfitPrice': None, 'triggerPrice': None, 'average': None, 'cost': None, 'amount': None, 'filled': None, 'remaining': None, 'status': None, 'fee': None, 'trades': [], 'reduceOnly': False, 'fees': [], 'stopPrice': None}
